# %%
import pandas as pd;
import matplotlib.pyplot as mplot;
df = pd.read_csv('data1.csv');

# %%
df
# Out:
#       Unnamed: 0   theta_1   theta_2   theta_3   theta_4   theta_5    theta_6
# 0     2017-01-01  0.756936 -1.467790  0.096136 -0.115306 -0.447908   0.902579
# 1     2017-01-02  0.767089  0.185797 -1.428536 -0.086443 -0.954288   1.930909
# 2     2017-01-03  0.404544  1.415887  0.443466  0.000200 -0.892351   2.449691
# 3     2017-01-04  1.313957 -1.804471 -0.836986  0.011785 -1.012518   1.182085
# 4     2017-01-05  0.209862  1.315868  0.140993 -0.046473 -1.417092   1.742433
# ...          ...       ...       ...       ...       ...       ...        ...
# 1090  2019-12-27 -1.520171 -1.128868  1.108275  0.936817  0.948045  11.755980
# 1091  2019-12-28  0.338910 -3.178251  1.484579  1.051123  1.025288  11.397092
# 1092  2019-12-29  0.263781  0.045725 -0.112476  0.823782  0.914111  10.918941
# 1093  2019-12-30 -0.425098 -1.002701 -0.834294  0.850904  0.801977  11.140722
# 1094  2019-12-31  0.848302  3.510521 -0.280626  0.967050  1.091803  11.989975
#
# [1095 rows x 7 columns]

# %%
date=df.copy()
df = df.set_index('Unnamed: 0');
df
# Out:
#              theta_1   theta_2   theta_3   theta_4   theta_5    theta_6
# Unnamed: 0
# 2017-01-01  0.756936 -1.467790  0.096136 -0.115306 -0.447908   0.902579
# 2017-01-02  0.767089  0.185797 -1.428536 -0.086443 -0.954288   1.930909
# 2017-01-03  0.404544  1.415887  0.443466  0.000200 -0.892351   2.449691
# 2017-01-04  1.313957 -1.804471 -0.836986  0.011785 -1.012518   1.182085
# 2017-01-05  0.209862  1.315868  0.140993 -0.046473 -1.417092   1.742433
# ...              ...       ...       ...       ...       ...        ...
# 2019-12-27 -1.520171 -1.128868  1.108275  0.936817  0.948045  11.755980
# 2019-12-28  0.338910 -3.178251  1.484579  1.051123  1.025288  11.397092
# 2019-12-29  0.263781  0.045725 -0.112476  0.823782  0.914111  10.918941
# 2019-12-30 -0.425098 -1.002701 -0.834294  0.850904  0.801977  11.140722
# 2019-12-31  0.848302  3.510521 -0.280626  0.967050  1.091803  11.989975
#
# [1095 rows x 6 columns]

# %%
df.plot(y='theta_1', use_index=True);
df.plot(y='theta_2', use_index=True);
df.plot(y='theta_3', use_index=True);
df.plot(y='theta_4', use_index=True);
df.plot(y='theta_5', use_index=True);
df.plot(y='theta_6', use_index=True);

# %%
df.plot()
# Out:
# <AxesSubplot:xlabel='Unnamed: 0'>

# %%
nobins = 40;
mplot.hist(df['theta_1'],bins=nobins)
mplot.hist(df['theta_2'],bins=nobins)
mplot.hist(df['theta_3'],bins=nobins)
mplot.hist(df['theta_4'],bins=nobins)
mplot.hist(df['theta_5'],bins=nobins)
mplot.hist(df['theta_6'],bins=nobins)
# Out:
# (array([ 1.,  1.,  0.,  3.,  5., 13., 12., 22., 28., 38., 41., 37., 32.,
#         40., 48., 41., 40., 31., 33., 39., 45., 38., 45., 44., 32., 26.,
#         41., 48., 42., 28., 35., 36., 40., 28., 19., 11., 17.,  8.,  2.,
#          5.]),
#  array([-1.65771908, -1.2685735 , -0.87942792, -0.49028234, -0.10113677,
#          0.28800881,  0.67715439,  1.06629997,  1.45544555,  1.84459113,
#          2.23373671,  2.62288229,  3.01202787,  3.40117345,  3.79031903,
#          4.1794646 ,  4.56861018,  4.95775576,  5.34690134,  5.73604692,
#          6.1251925 ,  6.51433808,  6.90348366,  7.29262924,  7.68177482,
#          8.07092039,  8.46006597,  8.84921155,  9.23835713,  9.62750271,
#         10.01664829, 10.40579387, 10.79493945, 11.18408503, 11.57323061,
#         11.96237619, 12.35152176, 12.74066734, 13.12981292, 13.5189585 ,
#         13.90810408]),
#  <BarContainer object of 40 artists>)

# %%
nobins = 40;
df.hist('theta_1',bins=nobins)
df.hist('theta_2',bins=nobins)
# Out:
# array([[<AxesSubplot:title={'center':'theta_2'}>]], dtype=object)

# %%
df.plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
date['Unnamed: 0']=pd.to_datetime(date['Unnamed: 0'],format='%Y/%m/%d')
formatedDate=date.loc[(date['Unnamed: 0']>'2017-12-31')&(date['Unnamed: 0']<'2019-01-01')]
formatedDate
# Out:
#     Unnamed: 0   theta_1   theta_2   theta_3   theta_4   theta_5   theta_6
# 365 2018-01-01  0.682693 -3.091767 -0.475717 -0.238530  0.036404  4.551359
# 366 2018-01-02 -0.283107 -0.979955  1.233933  0.158031 -0.097014  4.623086
# 367 2018-01-03  1.572221 -2.033528  2.196317  0.041347  0.009982  4.330249
# 368 2018-01-04 -1.042981  0.651530  1.060125  0.064832  0.036592  6.617830
# 369 2018-01-05 -1.392614 -2.570905 -0.600063 -0.015025  0.124576  5.577570
# ..         ...       ...       ...       ...       ...       ...       ...
# 725 2018-12-27  0.473556 -0.651265 -0.523058  0.076798  0.026654  8.459625
# 726 2018-12-28  1.433117  0.325632  0.905920  0.028891  0.040696  9.396884
# 727 2018-12-29  0.285428 -0.476290  1.082404  0.111482  0.031700  7.285139
# 728 2018-12-30  2.249273 -1.233575 -0.666277 -0.080878  0.004340  7.776090
# 729 2018-12-31  0.316409  5.673544 -0.964592 -0.150844 -0.091405  6.495294
#
# [365 rows x 7 columns]

# %%
formatedDate=formatedDate[['theta_1','theta_2','theta_3','theta_4']]
formatedDate.plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>
